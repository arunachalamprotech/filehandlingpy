# %%
import pandas as pd
file_path = "patients.csv"
df = pd.read_csv(file_path)
df
# Out:
#    patient_id first_name last_name gender date_of_birth  contact_number  \
# 0        P001      David  Williams      F    1955-06-04      6939585183
# 1        P002      Emily     Smith      F    1984-10-12      8228188767
# 2        P003      Laura     Jones      M    1977-08-21      8397029847
# 3        P004    Michael   Johnson      F    1981-02-20      9019443432
# 4        P005      David    Wilson      M    1960-06-23      7734463155
# 5        P006      Linda     Jones      M    1963-06-16      7561777264
# 6        P007       Alex   Johnson      F    1989-06-08      6278710077
# 7        P008      David     Davis      F    1976-07-05      7090558393
# 8        P009      Laura     Davis      M    1971-12-11      7060324619
# 9        P010    Michael    Taylor      M    2001-10-13      7081396733
# 10       P011      Emily     Jones      F    1966-12-04      8990604070
# 11       P012      Laura     Davis      F    1991-12-08      8135666049
# ...

# %%
data=pd.read_csv('patients.csv')
df=pd.DataFrame(data)
df.head(10)
# Out:
#   patient_id first_name last_name gender date_of_birth  contact_number  \
# 0       P001      David  Williams      F    1955-06-04      6939585183
# 1       P002      Emily     Smith      F    1984-10-12      8228188767
# 2       P003      Laura     Jones      M    1977-08-21      8397029847
# 3       P004    Michael   Johnson      F    1981-02-20      9019443432
# 4       P005      David    Wilson      M    1960-06-23      7734463155
# 5       P006      Linda     Jones      M    1963-06-16      7561777264
# 6       P007       Alex   Johnson      F    1989-06-08      6278710077
# 7       P008      David     Davis      F    1976-07-05      7090558393
# 8       P009      Laura     Davis      M    1971-12-11      7060324619
# 9       P010    Michael    Taylor      M    2001-10-13      7081396733
#
#         address registration_date insurance_provider insurance_number  \
# 0   789 Pine Rd        2022-06-23       WellnessCorp        INS840674
# ...

# %%
data=pd.read_csv('patients.csv')
df=pd.DataFrame(data)
df.tail(10)
# Out:
#    patient_id first_name last_name gender date_of_birth  contact_number  \
# 40       P041     Robert  Williams      M    1951-06-19      7020645498
# 41       P042       Jane     Smith      F    1954-08-22      7040069008
# 42       P043      Linda     Brown      M    1980-03-25      9127665406
# 43       P044     Robert    Taylor      F    1976-03-11      9449458981
# 44       P045      Linda    Miller      F    1966-04-25      7579616535
# 45       P046    Michael    Taylor      F    1986-09-01      8019925828
# 46       P047       Jane     Moore      M    1995-12-13      8715732851
# 47       P048      Emily    Miller      M    1983-03-24      8720989381
# 48       P049      David     Moore      M    1972-11-26      7712937941
# 49       P050      Laura    Wilson      M    1993-12-27      8301134730
#
#          address registration_date insurance_provider insurance_number  \
# 40   456 Oak Ave        2022-07-16       WellnessCorp        INS997059
# ...

# %%
df.isnull().sum()
# Out:
# patient_id            0
# first_name            0
# last_name             0
# gender                0
# date_of_birth         0
# contact_number        0
# address               0
# registration_date     0
# insurance_provider    0
# insurance_number      0
# email                 0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
data=pd.read_csv('billing.csv')
df=pd.DataFrame(data)
df.head(10)
# Out:
#   bill_id patient_id treatment_id   bill_date   amount payment_method  \
# 0    B001       P034         T001  2023-08-09  3941.97      Insurance
# 1    B002       P032         T002  2023-06-09  4158.44      Insurance
# 2    B003       P048         T003  2023-06-28  3731.55      Insurance
# 3    B004       P025         T004  2023-09-01  4799.86      Insurance
# 4    B005       P040         T005  2023-07-06   582.05    Credit Card
# 5    B006       P045         T006  2023-06-19  1381.00      Insurance
# 6    B007       P001         T007  2023-04-09   534.03           Cash
# 7    B008       P016         T008  2023-05-24  3413.64           Cash
# 8    B009       P039         T009  2023-03-05  4541.14    Credit Card
# 9    B010       P005         T010  2023-01-13  1595.67           Cash
#
#   payment_status
# 0        Pending
# 1           Paid
# 2           Paid
# 3         Failed
# 4        Pending
# 5        Pending
# 6         Failed
# 7         Failed
# 8           Paid
# ...

# %%
data=pd.read_csv('appointments.csv')
df=pd.DataFrame(data)
df.head(10)
# Out:
#   appointment_id patient_id doctor_id appointment_date appointment_time  \
# 0           A001       P034      D009       2023-08-09         15:15:00
# 1           A002       P032      D004       2023-06-09         14:30:00
# 2           A003       P048      D004       2023-06-28          8:00:00
# 3           A004       P025      D006       2023-09-01          9:15:00
# 4           A005       P040      D003       2023-07-06         12:45:00
# 5           A006       P045      D006       2023-06-19         16:15:00
# 6           A007       P001      D007       2023-04-09         10:30:00
# 7           A008       P016      D010       2023-05-24          8:45:00
# 8           A009       P039      D010       2023-03-05         13:45:00
# 9           A010       P005      D003       2023-01-13         15:30:00
#
#   reason_for_visit     status
# 0          Therapy  Scheduled
# 1          Therapy    No-show
# 2     Consultation  Cancelled
# 3     Consultation  Cancelled
# ...

# %%
data=pd.read_csv('doctors.csv')
df=pd.DataFrame(data)
df.head(5)
# Out:
#   doctor_id first_name last_name specialization  phone_number  \
# 0      D001      David    Taylor    Dermatology    8322010158
# 1      D002       Jane     Davis     Pediatrics    9004382050
# 2      D003       Jane     Smith     Pediatrics    8737740598
# 3      D004      David     Jones     Pediatrics    6594221991
# 4      D005      Sarah    Taylor    Dermatology    9118538547
#
#    years_experience   hospital_branch                         email
# 0                17   Westside Clinic  dr.david.taylor@hospital.com
# 1                24   Eastside Clinic    dr.jane.davis@hospital.com
# 2                19   Eastside Clinic    dr.jane.smith@hospital.com
# 3                28  Central Hospital   dr.david.jones@hospital.com
# 4                26  Central Hospital  dr.sarah.taylor@hospital.com

# %%
data=pd.read_csv('treatments.csv')
df=pd.DataFrame(data)
df.head(10)
# Out:
#   treatment_id appointment_id treatment_type         description     cost  \
# 0         T001           A001   Chemotherapy     Basic screening  3941.97
# 1         T002           A002            MRI   Advanced protocol  4158.44
# 2         T003           A003            MRI  Standard procedure  3731.55
# 3         T004           A004            MRI     Basic screening  4799.86
# 4         T005           A005            ECG  Standard procedure   582.05
# 5         T006           A006   Chemotherapy  Standard procedure  1381.00
# 6         T007           A007   Chemotherapy   Advanced protocol   534.03
# 7         T008           A008  Physiotherapy     Basic screening  3413.64
# 8         T009           A009  Physiotherapy  Standard procedure  4541.14
# 9         T010           A010  Physiotherapy  Standard procedure  1595.67
#
#   treatment_date
# 0     2023-08-09
# 1     2023-06-09
# 2     2023-06-28
# 3     2023-09-01
# 4     2023-07-06
# 5     2023-06-19
# 6     2023-04-09
# ...

# %%
#pivot table
data={
    'name':['David','David','Jane','Jane'],
    'subject':['math','science','math','science'],
    'marks':[90,80,70,60]
}
df=pd.DataFrame(data)

pivot_table=df.pivot_table(index='name',columns='subject',values='marks')
df.pivot
# Out:
# <bound method DataFrame.pivot of    name  subject  marks
# 0  arun     math     90
# 1  arun  science     80
# 2  bala     math     70
# 3  bala  science     60>
